# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing Data

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
rating_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(rating_url, sep='\t', low_memory=False)

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %% [markdown]
# # AKAs

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35843078 entries, 0 to 35843077
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB

# %%
akas = akas.replace({'\\N':np.nan})
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 35843073  tt9916852         5             Episódio #3.20     PT       pt
# 35843074  tt9916852         6             Episodio #3.20     IT       it
# 35843075  tt9916852         7               एपिसोड #3.20     IN       hi
# 35843076  tt9916856         1                   The Wind     DE      NaN
# 35843077  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 35843073          NaN            NaN               0
# 35843074          NaN            NaN               0
# 35843075          NaN            NaN               0
# 35843076  imdbDisplay            NaN               0
# 35843077     original            NaN               1
#
# [35843078 rows x 8 columns]

# %%
us = akas['region'] == 'US'
akas = akas[us]
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35842604  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35842674  tt9916620         1                          The Copeland Case
# 35842763  tt9916702         1              Loving London: The Playground
# 35842806  tt9916756         1                   Pretty Pretty Black Girl
# 35842822  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35842604     US      NaN  imdbDisplay                    NaN               0
# 35842674     US      NaN  imdbDisplay                    NaN               0
# 35842763     US      NaN          NaN                    NaN               0
# 35842806     US      NaN  imdbDisplay                    NaN               0
# 35842822     US      NaN  imdbDisplay                    NaN               0
#
# [1435435 rows x 8 columns]

# %% [markdown]
# # Basics

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837728 entries, 0 to 9837727
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 675.5+ MB

# %%
basics = basics.replace({'\\N':np.nan})
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9837723  tt9916848  tvEpisode              Episode #3.17
# 9837724  tt9916850  tvEpisode              Episode #3.19
# 9837725  tt9916852  tvEpisode              Episode #3.20
# 9837726  tt9916856      short                   The Wind
# 9837727  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9837723              Episode #3.17       0      2010     NaN            NaN
# 9837724              Episode #3.19       0      2010     NaN            NaN
# 9837725              Episode #3.20       0      2010     NaN            NaN
# 9837726                   The Wind       0      2015     NaN             27
# 9837727  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9837723         Action,Drama,Family
# 9837724         Action,Drama,Family
# 9837725         Action,Drama,Family
# 9837726                       Short
# 9837727  Adventure,Animation,Comedy
#
# [9837728 rows x 9 columns]

# %%
basics = basics.dropna(subset=["runtimeMinutes","genres"])
basics
# Out:
#             tconst  titleType                    primaryTitle  \
# 0        tt0000001      short                      Carmencita
# 1        tt0000002      short          Le clown et ses chiens
# 2        tt0000003      short                  Pauvre Pierrot
# 3        tt0000004      short                     Un bon bock
# 4        tt0000005      short                Blacksmith Scene
# ...            ...        ...                             ...
# 9837678  tt9916754      movie  Chico Albuquerque - Revelações
# 9837684  tt9916766  tvEpisode                  Episode #10.15
# 9837719  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 9837726  tt9916856      short                        The Wind
# 9837727  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                           originalTitle isAdult startYear endYear  \
# 0                            Carmencita       0      1894     NaN
# 1                Le clown et ses chiens       0      1892     NaN
# 2                        Pauvre Pierrot       0      1892     NaN
# 3                           Un bon bock       0      1892     NaN
# 4                      Blacksmith Scene       0      1893     NaN
# ...                                 ...     ...       ...     ...
# 9837678  Chico Albuquerque - Revelações       0      2013     NaN
# 9837684                  Episode #10.15       0      2019     NaN
# 9837719      Horrid Henry's Comic Caper       0      2014     NaN
# 9837726                        The Wind       0      2015     NaN
# 9837727       Horrid Henry Knows It All       0      2014     NaN
#
#         runtimeMinutes                       genres
# 0                    1            Documentary,Short
# 1                    5              Animation,Short
# 2                    4     Animation,Comedy,Romance
# 3                   12              Animation,Short
# 4                    1                 Comedy,Short
# ...                ...                          ...
# 9837678             49                  Documentary
# 9837684             43  Family,Game-Show,Reality-TV
# 9837719             11   Adventure,Animation,Comedy
# 9837726             27                        Short
# 9837727             10   Adventure,Animation,Comedy
#
# [2823465 rows x 9 columns]

# %%
basics = basics[(basics['titleType']=='movie')]
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9837494  tt9916362     movie
# 9837578  tt9916538     movie
# 9837619  tt9916622     movie
# 9837646  tt9916680     movie
# 9837678  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9837494                                              Coven
# 9837578                                Kuambil Lagi Hatiku
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9837646  De la ilusión al desconcierto: cine colombiano...
# 9837678                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9837494                                           Akelarre       0      2020
# 9837578                                Kuambil Lagi Hatiku       0      2019
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9837646  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9837678                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9837494     NaN             92               Drama,History
# 9837578     NaN            123                       Drama
# 9837619     NaN             57                 Documentary
# 9837646     NaN            100                 Documentary
# 9837678     NaN             49                 Documentary
#
# [382047 rows x 9 columns]

# %%
basics = basics[(basics['startYear'] > '1999') & (basics['startYear'] < '2022')]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9837494  tt9916362     movie
# 9837578  tt9916538     movie
# 9837619  tt9916622     movie
# 9837646  tt9916680     movie
# 9837678  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# ...                                                    ...
# 9837494                                              Coven
# 9837578                                Kuambil Lagi Hatiku
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9837646  De la ilusión al desconcierto: cine colombiano...
# 9837678                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 34803                                       Kate & Leopold       0      2001
# 61116            El tango del viudo y su espejo deformante       0      2020
# 67669                           The Other Side of the Wind       0      2018
# 86801                                    The Naked Monster       0      2005
# ...                                                    ...     ...       ...
# 9837494                                           Akelarre       0      2020
# 9837578                                Kuambil Lagi Hatiku       0      2019
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9837646  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9837678                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                  genres
# 13082       NaN             94             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 86801       NaN            100    Comedy,Horror,Sci-Fi
# ...         ...            ...                     ...
# 9837494     NaN             92           Drama,History
# 9837578     NaN            123                   Drama
# 9837619     NaN             57             Documentary
# 9837646     NaN            100             Documentary
# 9837678     NaN             49             Documentary
#
# [210470 rows x 9 columns]

# %%
#As we're only looking at movies, we don't need to look at endYear since it shows the year TV shows in the data ended
basics = basics.drop(columns=['endYear'])
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9837494  tt9916362     movie
# 9837578  tt9916538     movie
# 9837619  tt9916622     movie
# 9837646  tt9916680     movie
# 9837678  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# ...                                                    ...
# 9837494                                              Coven
# 9837578                                Kuambil Lagi Hatiku
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9837646  De la ilusión al desconcierto: cine colombiano...
# 9837678                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 34803                                       Kate & Leopold       0      2001
# 61116            El tango del viudo y su espejo deformante       0      2020
# 67669                           The Other Side of the Wind       0      2018
# 86801                                    The Naked Monster       0      2005
# ...                                                    ...     ...       ...
# 9837494                                           Akelarre       0      2020
# 9837578                                Kuambil Lagi Hatiku       0      2019
# 9837619        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9837646  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9837678                     Chico Albuquerque - Revelações       0      2013
#
#         runtimeMinutes                  genres
# 13082               94             Documentary
# 34803              118  Comedy,Fantasy,Romance
# 61116               70                   Drama
# 67669              122                   Drama
# 86801              100    Comedy,Horror,Sci-Fi
# ...                ...                     ...
# 9837494             92           Drama,History
# 9837578            123                   Drama
# 9837619             57             Documentary
# 9837646            100             Documentary
# 9837678             49             Documentary
#
# [210470 rows x 8 columns]

# %%
docs =basics['genres'].str.contains('documentary',case=False)
basics = basics[~docs]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9837401  tt9916170     movie
# 9837410  tt9916190     movie
# 9837449  tt9916270     movie
# 9837494  tt9916362     movie
# 9837578  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9837401                                      The Rehearsal
# 9837410                                          Safeguard
# 9837449                           Il talento del calabrone
# 9837494                                              Coven
# 9837578                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear  \
# 34803                               Kate & Leopold       0      2001
# 61116    El tango del viudo y su espejo deformante       0      2020
# 67669                   The Other Side of the Wind       0      2018
# 86801                            The Naked Monster       0      2005
# 93938                         Crime and Punishment       0      2002
# ...                                            ...     ...       ...
# 9837401                                   O Ensaio       0      2019
# 9837410                                  Safeguard       0      2020
# 9837449                   Il talento del calabrone       0      2020
# 9837494                                   Akelarre       0      2020
# 9837578                        Kuambil Lagi Hatiku       0      2019
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9837401             51                      Drama
# 9837410             95  Action,Adventure,Thriller
# 9837449             84                   Thriller
# 9837494             92              Drama,History
# 9837578            123                      Drama
#
# [138446 rows x 8 columns]

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 86801       True
# 93938       True
#            ...
# 9837401     True
# 9837410     True
# 9837449    False
# 9837494     True
# 9837578    False
# Name: tconst, Length: 138446, dtype: bool

# %%
basics = basics[keepers]
basics.info()
basics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81710 entries, 34803 to 9837494
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81710 non-null  object
#  1   titleType       81710 non-null  object
#  2   primaryTitle    81710 non-null  object
#  3   originalTitle   81710 non-null  object
#  4   isAdult         81710 non-null  object
#  5   startYear       81710 non-null  object
#  6   runtimeMinutes  81710 non-null  object
#  7   genres          81710 non-null  object
# dtypes: object(8)
# memory usage: 5.6+ MB
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9836866  tt9914942     movie
# 9837261  tt9915872     movie
# 9837401  tt9916170     movie
# 9837410  tt9916190     movie
# 9837494  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9836866                             Life Without Sara Amat
# 9837261                               The Last White Witch
# 9837401                                      The Rehearsal
# 9837410                                          Safeguard
# 9837494                                              Coven
#
#                                      originalTitle isAdult startYear  \
# 34803                               Kate & Leopold       0      2001
# 61116    El tango del viudo y su espejo deformante       0      2020
# 67669                   The Other Side of the Wind       0      2018
# 86801                            The Naked Monster       0      2005
# 93938                         Crime and Punishment       0      2002
# ...                                            ...     ...       ...
# 9836866                 La vida sense la Sara Amat       0      2019
# 9837261                  My Girlfriend is a Wizard       0      2019
# 9837401                                   O Ensaio       0      2019
# 9837410                                  Safeguard       0      2020
# 9837494                                   Akelarre       0      2020
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9836866             74                      Drama
# 9837261             97       Comedy,Drama,Fantasy
# 9837401             51                      Drama
# 9837410             95  Action,Adventure,Thriller
# 9837494             92              Drama,History
#
# [81710 rows x 8 columns]

# %% [markdown]
# # Ratings

# %%
ratings.info()
ratings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308743 entries, 0 to 1308742
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1308743 non-null  object
#  1   averageRating  1308743 non-null  float64
#  2   numVotes       1308743 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.0+ MB
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1969
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1815
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2612
# ...            ...            ...       ...
# 1308738  tt9916730            8.3        10
# 1308739  tt9916766            7.0        21
# 1308740  tt9916778            7.2        36
# 1308741  tt9916840            8.8         6
# 1308742  tt9916880            8.2         6
#
# [1308743 rows x 3 columns]

# %%
ratings = ratings.replace({'\\N':np.nan})
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1969
# 1        tt0000002            5.8       263
# 2        tt0000003            6.5      1815
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2612
# ...            ...            ...       ...
# 1308738  tt9916730            8.3        10
# 1308739  tt9916766            7.0        21
# 1308740  tt9916778            7.2        36
# 1308741  tt9916840            8.8         6
# 1308742  tt9916880            8.2         6
#
# [1308743 rows x 3 columns]

# %%
keepers2 =ratings['tconst'].isin(akas['titleId'])
keepers2
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1308738    False
# 1308739    False
# 1308740    False
# 1308741    False
# 1308742    False
# Name: tconst, Length: 1308743, dtype: bool

# %%
ratings = ratings[keepers2]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1969
# 1        tt0000002            5.8       263
# 4        tt0000005            6.2      2612
# 5        tt0000006            5.1       181
# 6        tt0000007            5.4       818
# ...            ...            ...       ...
# 1308704  tt9916200            8.1       229
# 1308705  tt9916204            8.1       262
# 1308712  tt9916348            8.3        18
# 1308713  tt9916362            6.4      5320
# 1308718  tt9916428            3.8        14
#
# [497874 rows x 3 columns]

# %% [markdown]
# # Exporting Data and Finalizing it

# %%
import os as os
os.makedirs('Data/',exist_ok=True) 
os.listdir("Data/")
# Out:
# ['title.akas.tsv.gz', 'title.ratings.tsv.gz', 'title_basics.csv.gz']

# %%
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0       2001
# 1  El tango del viudo y su espejo deformante        0       2020
# 2                 The Other Side of the Wind        0       2018
# 3                          The Naked Monster        0       2005
# 4                       Crime and Punishment        0       2002
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
akas.to_csv("Data/title.akas.tsv.gz",compression='gzip',index=False)

# %%
akas = pd.read_csv("Data/title.akas.tsv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
ratings.to_csv("Data/title.ratings.tsv.gz",compression='gzip',index=False)

# %%
ratings = pd.read_csv("Data/title.ratings.tsv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1969
# 1  tt0000002            5.8       263
# 2  tt0000005            6.2      2612
# 3  tt0000006            5.1       181
# 4  tt0000007            5.4       818
